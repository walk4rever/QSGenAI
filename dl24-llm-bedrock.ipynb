# %% [markdown]
# # Amazon Bedrock API

# %%
# Test the Bedrock setup

import boto3
bedrock = boto3.client(service_name='bedrock')

bedrock.get_foundation_model(modelIdentifier='anthropic.claude-v2')
# Out:
# {'ResponseMetadata': {'RequestId': '9488cc5e-d92b-483c-981e-39bd9cc7d52d',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 24 Mar 2024 06:34:55 GMT',
#    'content-type': 'application/json',
#    'content-length': '370',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '9488cc5e-d92b-483c-981e-39bd9cc7d52d'},
#   'RetryAttempts': 0},
#  'modelDetails': {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2',
#   'modelId': 'anthropic.claude-v2',
#   'modelName': 'Claude',
#   'providerName': 'Anthropic',
#   'inputModalities': ['TEXT'],
#   'outputModalities': ['TEXT'],
#   'responseStreamingSupported': True,
#   'customizationsSupported': [],
#   'inferenceTypesSupported': ['ON_DEMAND'],
#   'modelLifecycle': {'status': 'ACTIVE'}}}

# %%
# Test Bedrock Runtime

import boto3
import json

bedrock = boto3.client(service_name='bedrock-runtime')

body = json.dumps({
    "prompt": "\n\nHuman:explain black holes to 8th graders?\n\nAssistant:",
    "max_tokens_to_sample": 1024,
    "temperature": 0.1,
    "top_p": 0.9,
})

modelId = 'anthropic.claude-v2'

accept = 'application/json'

contentType = 'application/json'

response = bedrock.invoke_model(body=body, modelId=modelId, accept=accept, contentType=contentType)

response_body = json.loads(response.get('body').read())

# text
print(response_body.get('completion'))
# Out:
#  Here is a simple explanation of black holes for 8th graders:
#
# - A black hole is a region in space where gravity is so strong that nothing can escape from it, even light. This region is called the event horizon.
#
# - Black holes form when very massive stars collapse. When the star runs out of nuclear fuel, gravity makes it collapse. The matter gets compressed into a very small space, creating a black hole.
#
# - Black holes are called "black" because they absorb all the light that hits them. They don't reflect or emit any light that we can detect. So they appear completely black.
#
# - At the center of a black hole is a gravitational singularity, where gravity becomes infinite. We don't know what happens inside the singularity.
#
# - Black holes have such strong gravity that not even light can escape once it crosses the event horizon. Anything that gets too close will get sucked in.
#
# - Black holes can't be directly observed because they don't emit light. But we can detect them from their effects on nearby stars and gas clouds. As matter swirls toward the black hole, it heats up and emits X-rays that we can detect.
#
# - Supermassive black holes are thought to be at the center of most galaxies, including our Milky Way galaxy. They have masses millions to billions times that of our Sun.
#
# Let me know if you need any clarification or have additional questions! The key ideas are that black holes form from collapsed stars, have intense gravity, trap everything including light, and can only be detected indirectly.

# %%
# Invoke the model with streaming code

import boto3
import json

brt = boto3.client(service_name='bedrock-runtime')

body = json.dumps({
    'prompt': '\n\nHuman: write an essay for living on mars in 1000 words\n\nAssistant:',
    'max_tokens_to_sample': 1024
})
                   
response = brt.invoke_model_with_response_stream(
    modelId='anthropic.claude-v2', 
    body=body
)
    
stream = response.get('body')
if stream:
    for event in stream:
        chunk = event.get('chunk')
        if chunk:
            print(json.loads(chunk.get('bytes').decode()))
# Out:
# {'completion': ' Here', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' 99', 'stop_reason': None, 'stop': None}
# {'completion': '7', 'stop_reason': None, 'stop': None}
# {'completion': ' word', 'stop_reason': None, 'stop': None}
# {'completion': ' essay', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' living', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ':', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nLiving', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nMars', 'stop_reason': None, 'stop': None}
# {'completion': ' has', 'stop_reason': None, 'stop': None}
# {'completion': ' long', 'stop_reason': None, 'stop': None}
# {'completion': ' captured', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' imagination', 'stop_reason': None, 'stop': None}
# {'completion': ' as', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' potential', 'stop_reason': None, 'stop': None}
# {'completion': ' second', 'stop_reason': None, 'stop': None}
# {'completion': ' home', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' humanity', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' red', 'stop_reason': None, 'stop': None}
# {'completion': ' planet', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' most', 'stop_reason': None, 'stop': None}
# {'completion': ' earth', 'stop_reason': None, 'stop': None}
# {'completion': '-', 'stop_reason': None, 'stop': None}
# {'completion': 'like', 'stop_reason': None, 'stop': None}
# {'completion': ' world', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' our', 'stop_reason': None, 'stop': None}
# {'completion': ' solar', 'stop_reason': None, 'stop': None}
# {'completion': ' system', 'stop_reason': None, 'stop': None}
# {'completion': ' besides', 'stop_reason': None, 'stop': None}
# {'completion': ' our', 'stop_reason': None, 'stop': None}
# {'completion': ' own', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' thus', 'stop_reason': None, 'stop': None}
# {'completion': ' presents', 'stop_reason': None, 'stop': None}
# {'completion': ' an', 'stop_reason': None, 'stop': None}
# {'completion': ' intriguing', 'stop_reason': None, 'stop': None}
# {'completion': ' possibility', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' future', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ization', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' While', 'stop_reason': None, 'stop': None}
# {'completion': ' living', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' poses', 'stop_reason': None, 'stop': None}
# {'completion': ' many', 'stop_reason': None, 'stop': None}
# {'completion': ' challenges', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' difficulties', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' it', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' offers', 'stop_reason': None, 'stop': None}
# {'completion': ' numerous', 'stop_reason': None, 'stop': None}
# {'completion': ' opportunities', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' benefits', 'stop_reason': None, 'stop': None}
# {'completion': ' that', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' profoundly', 'stop_reason': None, 'stop': None}
# {'completion': ' reshape', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' civilization', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '  ', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nThe', 'stop_reason': None, 'stop': None}
# {'completion': ' most', 'stop_reason': None, 'stop': None}
# {'completion': ' immediate', 'stop_reason': None, 'stop': None}
# {'completion': ' challenge', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' living', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' surviving', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' planet', 'stop_reason': None, 'stop': None}
# {'completion': "'s", 'stop_reason': None, 'stop': None}
# {'completion': ' inh', 'stop_reason': None, 'stop': None}
# {'completion': 'osp', 'stop_reason': None, 'stop': None}
# {'completion': 'itable', 'stop_reason': None, 'stop': None}
# {'completion': ' surface', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' atmosphere', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' thin', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' cold', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' with', 'stop_reason': None, 'stop': None}
# {'completion': ' barely', 'stop_reason': None, 'stop': None}
# {'completion': ' 1', 'stop_reason': None, 'stop': None}
# {'completion': '%', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' air', 'stop_reason': None, 'stop': None}
# {'completion': ' pressure', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' temperatures', 'stop_reason': None, 'stop': None}
# {'completion': ' that', 'stop_reason': None, 'stop': None}
# {'completion': ' can', 'stop_reason': None, 'stop': None}
# {'completion': ' drop', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' -', 'stop_reason': None, 'stop': None}
# {'completion': '140', 'stop_reason': None, 'stop': None}
# {'completion': ' degrees', 'stop_reason': None, 'stop': None}
# {'completion': ' F', 'stop_reason': None, 'stop': None}
# {'completion': 'ahrenheit', 'stop_reason': None, 'stop': None}
# {'completion': ' at', 'stop_reason': None, 'stop': None}
# {'completion': ' night', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' planet', 'stop_reason': None, 'stop': None}
# {'completion': ' lacks', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' protective', 'stop_reason': None, 'stop': None}
# {'completion': ' global', 'stop_reason': None, 'stop': None}
# {'completion': ' magnetic', 'stop_reason': None, 'stop': None}
# {'completion': ' field', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' resulting', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' high', 'stop_reason': None, 'stop': None}
# {'completion': ' levels', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' radiation', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' solar', 'stop_reason': None, 'stop': None}
# {'completion': ' storms', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' cosmic', 'stop_reason': None, 'stop': None}
# {'completion': ' rays', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Growing', 'stop_reason': None, 'stop': None}
# {'completion': ' food', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' difficult', 'stop_reason': None, 'stop': None}
# {'completion': ' with', 'stop_reason': None, 'stop': None}
# {'completion': ' freezing', 'stop_reason': None, 'stop': None}
# {'completion': ' temperatures', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' toxic', 'stop_reason': None, 'stop': None}
# {'completion': ' soil', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' lack', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' easily', 'stop_reason': None, 'stop': None}
# {'completion': ' accessible', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Significant', 'stop_reason': None, 'stop': None}
# {'completion': ' advances', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' habitat', 'stop_reason': None, 'stop': None}
# {'completion': ' construction', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' spaces', 'stop_reason': None, 'stop': None}
# {'completion': 'uit', 'stop_reason': None, 'stop': None}
# {'completion': ' design', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' indoor', 'stop_reason': None, 'stop': None}
# {'completion': ' agriculture', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' access', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' subsurface', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' required', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' make', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' colonies', 'stop_reason': None, 'stop': None}
# {'completion': ' viable', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nDespite', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' harsh', 'stop_reason': None, 'stop': None}
# {'completion': ' environment', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' does', 'stop_reason': None, 'stop': None}
# {'completion': ' offer', 'stop_reason': None, 'stop': None}
# {'completion': ' some', 'stop_reason': None, 'stop': None}
# {'completion': ' critical', 'stop_reason': None, 'stop': None}
# {'completion': ' resources', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' most', 'stop_reason': None, 'stop': None}
# {'completion': ' notably', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' form', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' ice', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' V', 'stop_reason': None, 'stop': None}
# {'completion': 'ast', 'stop_reason': None, 'stop': None}
# {'completion': ' deposits', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' ice', 'stop_reason': None, 'stop': None}
# {'completion': ' have', 'stop_reason': None, 'stop': None}
# {'completion': ' been', 'stop_reason': None, 'stop': None}
# {'completion': ' discovered', 'stop_reason': None, 'stop': None}
# {'completion': ' under', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' surface', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' polar', 'stop_reason': None, 'stop': None}
# {'completion': ' ice', 'stop_reason': None, 'stop': None}
# {'completion': ' caps', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Access', 'stop_reason': None, 'stop': None}
# {'completion': 'ing', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' pur', 'stop_reason': None, 'stop': None}
# {'completion': 'ifying', 'stop_reason': None, 'stop': None}
# {'completion': ' this', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' provide', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' with', 'stop_reason': None, 'stop': None}
# {'completion': ' drinking', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' as', 'stop_reason': None, 'stop': None}
# {'completion': ' well', 'stop_reason': None, 'stop': None}
# {'completion': ' as', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' vital', 'stop_reason': None, 'stop': None}
# {'completion': ' source', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' oxygen', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' hydrogen', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' rocket', 'stop_reason': None, 'stop': None}
# {'completion': ' fuel', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' soil', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' contains', 'stop_reason': None, 'stop': None}
# {'completion': ' all', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' elemental', 'stop_reason': None, 'stop': None}
# {'completion': ' ingredients', 'stop_reason': None, 'stop': None}
# {'completion': ' necessary', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' agriculture', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' though', 'stop_reason': None, 'stop': None}
# {'completion': ' it', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' need', 'stop_reason': None, 'stop': None}
# {'completion': ' heavy', 'stop_reason': None, 'stop': None}
# {'completion': ' treatment', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' remove', 'stop_reason': None, 'stop': None}
# {'completion': ' dangerous', 'stop_reason': None, 'stop': None}
# {'completion': ' per', 'stop_reason': None, 'stop': None}
# {'completion': 'chlor', 'stop_reason': None, 'stop': None}
# {'completion': 'ates', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' With', 'stop_reason': None, 'stop': None}
# {'completion': ' enclosed', 'stop_reason': None, 'stop': None}
# {'completion': ' green', 'stop_reason': None, 'stop': None}
# {'completion': 'houses', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' hydro', 'stop_reason': None, 'stop': None}
# {'completion': 'pon', 'stop_reason': None, 'stop': None}
# {'completion': 'ics', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' potentially', 'stop_reason': None, 'stop': None}
# {'completion': ' grow', 'stop_reason': None, 'stop': None}
# {'completion': ' food', 'stop_reason': None, 'stop': None}
# {'completion': ' crops', 'stop_reason': None, 'stop': None}
# {'completion': ' supplemented', 'stop_reason': None, 'stop': None}
# {'completion': ' with', 'stop_reason': None, 'stop': None}
# {'completion': ' synthesized', 'stop_reason': None, 'stop': None}
# {'completion': ' nutrients', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nFor', 'stop_reason': None, 'stop': None}
# {'completion': ' energy', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' receives', 'stop_reason': None, 'stop': None}
# {'completion': ' abundant', 'stop_reason': None, 'stop': None}
# {'completion': ' sunlight', 'stop_reason': None, 'stop': None}
# {'completion': ' compared', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' more', 'stop_reason': None, 'stop': None}
# {'completion': ' distant', 'stop_reason': None, 'stop': None}
# {'completion': ' destinations', 'stop_reason': None, 'stop': None}
# {'completion': ' like', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' J', 'stop_reason': None, 'stop': None}
# {'completion': 'ov', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' mo', 'stop_reason': None, 'stop': None}
# {'completion': 'ons', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Solar', 'stop_reason': None, 'stop': None}
# {'completion': ' arrays', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' likely', 'stop_reason': None, 'stop': None}
# {'completion': ' provide', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' bulk', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' colony', 'stop_reason': None, 'stop': None}
# {'completion': "'s", 'stop_reason': None, 'stop': None}
# {'completion': ' energy', 'stop_reason': None, 'stop': None}
# {'completion': ' needs', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Nuclear', 'stop_reason': None, 'stop': None}
# {'completion': ' power', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' another', 'stop_reason': None, 'stop': None}
# {'completion': ' strong', 'stop_reason': None, 'stop': None}
# {'completion': ' possibility', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Radio', 'stop_reason': None, 'stop': None}
# {'completion': 'isot', 'stop_reason': None, 'stop': None}
# {'completion': 'ope', 'stop_reason': None, 'stop': None}
# {'completion': ' generators', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' provide', 'stop_reason': None, 'stop': None}
# {'completion': ' warmth', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' electricity', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' early', 'stop_reason': None, 'stop': None}
# {'completion': ' out', 'stop_reason': None, 'stop': None}
# {'completion': 'posts', 'stop_reason': None, 'stop': None}
# {'completion': ' before', 'stop_reason': None, 'stop': None}
# {'completion': ' larger', 'stop_reason': None, 'stop': None}
# {'completion': ' scale', 'stop_reason': None, 'stop': None}
# {'completion': ' infrastructure', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' established', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' St', 'stop_reason': None, 'stop': None}
# {'completion': 'oring', 'stop_reason': None, 'stop': None}
# {'completion': ' energy', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' critical', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' lasting', 'stop_reason': None, 'stop': None}
# {'completion': ' through', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' long', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' fr', 'stop_reason': None, 'stop': None}
# {'completion': 'ig', 'stop_reason': None, 'stop': None}
# {'completion': 'id', 'stop_reason': None, 'stop': None}
# {'completion': ' nights', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nPer', 'stop_reason': None, 'stop': None}
# {'completion': 'manent', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' colonies', 'stop_reason': None, 'stop': None}
# {'completion': ' face', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' key', 'stop_reason': None, 'stop': None}
# {'completion': ' log', 'stop_reason': None, 'stop': None}
# {'completion': 'istical', 'stop_reason': None, 'stop': None}
# {'completion': ' dilemma', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' having', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' bring', 'stop_reason': None, 'stop': None}
# {'completion': ' most', 'stop_reason': None, 'stop': None}
# {'completion': ' supplies', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': ' or', 'stop_reason': None, 'stop': None}
# {'completion': ' extract', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' manufacture', 'stop_reason': None, 'stop': None}
# {'completion': ' them', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': '-', 'stop_reason': None, 'stop': None}
# {'completion': 'site', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' While', 'stop_reason': None, 'stop': None}
# {'completion': ' tools', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' computers', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' other', 'stop_reason': None, 'stop': None}
# {'completion': ' equipment', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' shipped', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' cost', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' transport', 'stop_reason': None, 'stop': None}
# {'completion': 'ing', 'stop_reason': None, 'stop': None}
# {'completion': ' basic', 'stop_reason': None, 'stop': None}
# {'completion': ' resources', 'stop_reason': None, 'stop': None}
# {'completion': ' like', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' fuel', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' metals', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' gases', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' prohibit', 'stop_reason': None, 'stop': None}
# {'completion': 'ively', 'stop_reason': None, 'stop': None}
# {'completion': ' expensive', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' In', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' long', 'stop_reason': None, 'stop': None}
# {'completion': ' run', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' colony', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' need', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' achieve', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' high', 'stop_reason': None, 'stop': None}
# {'completion': ' level', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' self', 'stop_reason': None, 'stop': None}
# {'completion': '-', 'stop_reason': None, 'stop': None}
# {'completion': 'suff', 'stop_reason': None, 'stop': None}
# {'completion': 'iciency', 'stop_reason': None, 'stop': None}
# {'completion': ' by', 'stop_reason': None, 'stop': None}
# {'completion': ' extracting', 'stop_reason': None, 'stop': None}
# {'completion': ' water', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' ice', 'stop_reason': None, 'stop': None}
# {'completion': ' deposits', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' harvesting', 'stop_reason': None, 'stop': None}
# {'completion': ' gases', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' atmosphere', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' smel', 'stop_reason': None, 'stop': None}
# {'completion': 'ting', 'stop_reason': None, 'stop': None}
# {'completion': ' metals', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' soil', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' manufacturing', 'stop_reason': None, 'stop': None}
# {'completion': ' pl', 'stop_reason': None, 'stop': None}
# {'completion': 'astics', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' other', 'stop_reason': None, 'stop': None}
# {'completion': ' goods', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Either', 'stop_reason': None, 'stop': None}
# {'completion': ' robotic', 'stop_reason': None, 'stop': None}
# {'completion': ' or', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' miners', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' likely', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' essential', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nFor', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' thriving', 'stop_reason': None, 'stop': None}
# {'completion': ' workforce', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' itself', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' offer', 'stop_reason': None, 'stop': None}
# {'completion': ' some', 'stop_reason': None, 'stop': None}
# {'completion': ' key', 'stop_reason': None, 'stop': None}
# {'completion': ' benefits', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Its', 'stop_reason': None, 'stop': None}
# {'completion': ' lower', 'stop_reason': None, 'stop': None}
# {'completion': ' gravity', 'stop_reason': None, 'stop': None}
# {'completion': ' -', 'stop_reason': None, 'stop': None}
# {'completion': ' around', 'stop_reason': None, 'stop': None}
# {'completion': ' 38', 'stop_reason': None, 'stop': None}
# {'completion': '%', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': "'s", 'stop_reason': None, 'stop': None}
# {'completion': ' -', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' allow', 'stop_reason': None, 'stop': None}
# {'completion': ' people', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' work', 'stop_reason': None, 'stop': None}
# {'completion': ' longer', 'stop_reason': None, 'stop': None}
# {'completion': ' hours', 'stop_reason': None, 'stop': None}
# {'completion': ' with', 'stop_reason': None, 'stop': None}
# {'completion': ' less', 'stop_reason': None, 'stop': None}
# {'completion': ' fatigue', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' enable', 'stop_reason': None, 'stop': None}
# {'completion': ' easier', 'stop_reason': None, 'stop': None}
# {'completion': ' construction', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' habitats', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' themselves', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' live', 'stop_reason': None, 'stop': None}
# {'completion': ' healthier', 'stop_reason': None, 'stop': None}
# {'completion': ' lives', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' as', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' effects', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' aging', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' reduced', 'stop_reason': None, 'stop': None}
# {'completion': ' in', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' lower', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' gravity', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Transportation', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' construction', 'stop_reason': None, 'stop': None}
# {'completion': ' projects', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' benefit', 'stop_reason': None, 'stop': None}
# {'completion': ' greatly', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' reduced', 'stop_reason': None, 'stop': None}
# {'completion': ' gravitational', 'stop_reason': None, 'stop': None}
# {'completion': ' pull', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Draw', 'stop_reason': None, 'stop': None}
# {'completion': 'backs', 'stop_reason': None, 'stop': None}
# {'completion': ' include', 'stop_reason': None, 'stop': None}
# {'completion': ' bone', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' muscle', 'stop_reason': None, 'stop': None}
# {'completion': ' loss', 'stop_reason': None, 'stop': None}
# {'completion': ' over', 'stop_reason': None, 'stop': None}
# {'completion': ' time', 'stop_reason': None, 'stop': None}
# {'completion': ' spent', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' without', 'stop_reason': None, 'stop': None}
# {'completion': ' exercise', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Advanced', 'stop_reason': None, 'stop': None}
# {'completion': ' medicine', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' help', 'stop_reason': None, 'stop': None}
# {'completion': ' address', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' negative', 'stop_reason': None, 'stop': None}
# {'completion': ' health', 'stop_reason': None, 'stop': None}
# {'completion': ' effects', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '   ', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nMars', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' need', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' establish', 'stop_reason': None, 'stop': None}
# {'completion': ' political', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' economic', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' social', 'stop_reason': None, 'stop': None}
# {'completion': ' systems', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' maintain', 'stop_reason': None, 'stop': None}
# {'completion': ' order', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' distribute', 'stop_reason': None, 'stop': None}
# {'completion': ' resources', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' great', 'stop_reason': None, 'stop': None}
# {'completion': ' distances', 'stop_reason': None, 'stop': None}
# {'completion': ' involved', 'stop_reason': None, 'stop': None}
# {'completion': ' mean', 'stop_reason': None, 'stop': None}
# {'completion': ' any', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' colony', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' necessarily', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' isolated', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' direct', 'stop_reason': None, 'stop': None}
# {'completion': ' oversight', 'stop_reason': None, 'stop': None}
# {'completion': ' by', 'stop_reason': None, 'stop': None}
# {'completion': ' any', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': ' nation', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' A', 'stop_reason': None, 'stop': None}
# {'completion': ' degree', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' autonomy', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' self', 'stop_reason': None, 'stop': None}
# {'completion': '-', 'stop_reason': None, 'stop': None}
# {'completion': 'g', 'stop_reason': None, 'stop': None}
# {'completion': 'overn', 'stop_reason': None, 'stop': None}
# {'completion': 'ance', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' essential', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Trading', 'stop_reason': None, 'stop': None}
# {'completion': ' scarce', 'stop_reason': None, 'stop': None}
# {'completion': ' resources', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' services', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' collecting', 'stop_reason': None, 'stop': None}
# {'completion': ' taxes', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' fund', 'stop_reason': None, 'stop': None}
# {'completion': ' infrastructure', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' enforcing', 'stop_reason': None, 'stop': None}
# {'completion': ' laws', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' handle', 'stop_reason': None, 'stop': None}
# {'completion': ' disputes', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' crime', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' all', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' required', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Education', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' recreation', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' mechanisms', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' social', 'stop_reason': None, 'stop': None}
# {'completion': ' interaction', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' help', 'stop_reason': None, 'stop': None}
# {'completion': ' maintain', 'stop_reason': None, 'stop': None}
# {'completion': ' psychological', 'stop_reason': None, 'stop': None}
# {'completion': ' health', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Settlement', 'stop_reason': None, 'stop': None}
# {'completion': 's', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' be', 'stop_reason': None, 'stop': None}
# {'completion': ' modeled', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' everything', 'stop_reason': None, 'stop': None}
# {'completion': ' from', 'stop_reason': None, 'stop': None}
# {'completion': ' cooperative', 'stop_reason': None, 'stop': None}
# {'completion': ' comm', 'stop_reason': None, 'stop': None}
# {'completion': 'unes', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' entrepreneur', 'stop_reason': None, 'stop': None}
# {'completion': 'ial', 'stop_reason': None, 'stop': None}
# {'completion': ' free', 'stop_reason': None, 'stop': None}
# {'completion': ' markets', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nFor', 'stop_reason': None, 'stop': None}
# {'completion': ' pione', 'stop_reason': None, 'stop': None}
# {'completion': 'ers', 'stop_reason': None, 'stop': None}
# {'completion': ' willing', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' undertake', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' risks', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' living', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' holds', 'stop_reason': None, 'stop': None}
# {'completion': ' enormous', 'stop_reason': None, 'stop': None}
# {'completion': ' opportunities', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Full', 'stop_reason': None, 'stop': None}
# {'completion': '-', 'stop_reason': None, 'stop': None}
# {'completion': 'time', 'stop_reason': None, 'stop': None}
# {'completion': ' residence', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' another', 'stop_reason': None, 'stop': None}
# {'completion': ' planet', 'stop_reason': None, 'stop': None}
# {'completion': ' represents', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' bold', 'stop_reason': None, 'stop': None}
# {'completion': ' step', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' humankind', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' gain', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' opportunity', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' explore', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' new', 'stop_reason': None, 'stop': None}
# {'completion': ' world', 'stop_reason': None, 'stop': None}
# {'completion': ' first', 'stop_reason': None, 'stop': None}
# {'completion': 'hand', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' expand', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' horiz', 'stop_reason': None, 'stop': None}
# {'completion': 'ons', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' experience', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' The', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ization', 'stop_reason': None, 'stop': None}
# {'completion': ' process', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' drive', 'stop_reason': None, 'stop': None}
# {'completion': ' innovation', 'stop_reason': None, 'stop': None}
# {'completion': ' across', 'stop_reason': None, 'stop': None}
# {'completion': ' fields', 'stop_reason': None, 'stop': None}
# {'completion': ' like', 'stop_reason': None, 'stop': None}
# {'completion': ' medicine', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' agriculture', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' construction', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' manufacturing', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' robot', 'stop_reason': None, 'stop': None}
# {'completion': 'ics', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' energy', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' transportation', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' Technologies', 'stop_reason': None, 'stop': None}
# {'completion': ' created', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' enable', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' colony', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' also', 'stop_reason': None, 'stop': None}
# {'completion': ' benefit', 'stop_reason': None, 'stop': None}
# {'completion': ' life', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' And', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' permanent', 'stop_reason': None, 'stop': None}
# {'completion': ' settlement', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' would', 'stop_reason': None, 'stop': None}
# {'completion': ' provide', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' fo', 'stop_reason': None, 'stop': None}
# {'completion': 'oth', 'stop_reason': None, 'stop': None}
# {'completion': 'old', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' humanity', 'stop_reason': None, 'stop': None}
# {'completion': "'s", 'stop_reason': None, 'stop': None}
# {'completion': ' expansion', 'stop_reason': None, 'stop': None}
# {'completion': ' into', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' solar', 'stop_reason': None, 'stop': None}
# {'completion': ' system', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' serve', 'stop_reason': None, 'stop': None}
# {'completion': ' as', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' backup', 'stop_reason': None, 'stop': None}
# {'completion': ' location', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': ' preserving', 'stop_reason': None, 'stop': None}
# {'completion': ' our', 'stop_reason': None, 'stop': None}
# {'completion': ' species', 'stop_reason': None, 'stop': None}
# {'completion': ' should', 'stop_reason': None, 'stop': None}
# {'completion': ' Earth', 'stop_reason': None, 'stop': None}
# {'completion': ' suffer', 'stop_reason': None, 'stop': None}
# {'completion': ' a', 'stop_reason': None, 'stop': None}
# {'completion': ' global', 'stop_reason': None, 'stop': None}
# {'completion': ' catastrophe', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' ', 'stop_reason': None, 'stop': None}
# {'completion': '\n\nWhile', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' challenges', 'stop_reason': None, 'stop': None}
# {'completion': ' are', 'stop_reason': None, 'stop': None}
# {'completion': ' immense', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' living', 'stop_reason': None, 'stop': None}
# {'completion': ' on', 'stop_reason': None, 'stop': None}
# {'completion': ' Mars', 'stop_reason': None, 'stop': None}
# {'completion': ' is', 'stop_reason': None, 'stop': None}
# {'completion': ' an', 'stop_reason': None, 'stop': None}
# {'completion': ' epic', 'stop_reason': None, 'stop': None}
# {'completion': ' opportunity', 'stop_reason': None, 'stop': None}
# {'completion': ' that', 'stop_reason': None, 'stop': None}
# {'completion': ' humanity', 'stop_reason': None, 'stop': None}
# {'completion': ' should', 'stop_reason': None, 'stop': None}
# {'completion': ' strive', 'stop_reason': None, 'stop': None}
# {'completion': ' for', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': ' With', 'stop_reason': None, 'stop': None}
# {'completion': ' our', 'stop_reason': None, 'stop': None}
# {'completion': ' growing', 'stop_reason': None, 'stop': None}
# {'completion': ' understanding', 'stop_reason': None, 'stop': None}
# {'completion': ' of', 'stop_reason': None, 'stop': None}
# {'completion': ' the', 'stop_reason': None, 'stop': None}
# {'completion': ' planet', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' dedication', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' scientific', 'stop_reason': None, 'stop': None}
# {'completion': ' advances', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' courage', 'stop_reason': None, 'stop': None}
# {'completion': ' to', 'stop_reason': None, 'stop': None}
# {'completion': ' undertake', 'stop_reason': None, 'stop': None}
# {'completion': ' bold', 'stop_reason': None, 'stop': None}
# {'completion': ' vent', 'stop_reason': None, 'stop': None}
# {'completion': 'ures', 'stop_reason': None, 'stop': None}
# {'completion': ',', 'stop_reason': None, 'stop': None}
# {'completion': ' future', 'stop_reason': None, 'stop': None}
# {'completion': ' Mart', 'stop_reason': None, 'stop': None}
# {'completion': 'ian', 'stop_reason': None, 'stop': None}
# {'completion': ' colon', 'stop_reason': None, 'stop': None}
# {'completion': 'ists', 'stop_reason': None, 'stop': None}
# {'completion': ' could', 'stop_reason': None, 'stop': None}
# {'completion': ' realize', 'stop_reason': None, 'stop': None}
# {'completion': ' this', 'stop_reason': None, 'stop': None}
# {'completion': ' amazing', 'stop_reason': None, 'stop': None}
# {'completion': ' potential', 'stop_reason': None, 'stop': None}
# {'completion': ' and', 'stop_reason': None, 'stop': None}
# {'completion': ' forever', 'stop_reason': None, 'stop': None}
# {'completion': ' change', 'stop_reason': None, 'stop': None}
# {'completion': ' human', 'stop_reason': None, 'stop': None}
# {'completion': ' destiny', 'stop_reason': None, 'stop': None}
# {'completion': '.', 'stop_reason': None, 'stop': None}
# {'completion': '', 'stop_reason': 'stop_sequence', 'stop': '\n\nHuman:', 'amazon-bedrock-invocationMetrics': {'inputTokenCount': 19, 'outputTokenCount': 955, 'invocationLatency': 43728, 'firstByteLatency': 563}}

# %%
! pip install transformers datasets

# %%
import boto3 
bedrock = boto3.client(service_name='bedrock')

bedrock.list_foundation_models()
# Out:
# {'ResponseMetadata': {'RequestId': '2810efaa-0897-480d-96f7-94dbb783aa29',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 24 Mar 2024 06:36:13 GMT',
#    'content-type': 'application/json',
#    'content-length': '18333',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '2810efaa-0897-480d-96f7-94dbb783aa29'},
#   'RetryAttempts': 0},
#  'modelSummaries': [{'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-tg1-large',
#    'modelId': 'amazon.titan-tg1-large',
#    'modelName': 'Titan Text Large',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-embed-g1-text-02',
#    'modelId': 'amazon.titan-embed-g1-text-02',
#    'modelName': 'Titan Text Embeddings v2',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['EMBEDDING'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-text-lite-v1:0:4k',
#    'modelId': 'amazon.titan-text-lite-v1:0:4k',
#    'modelName': 'Titan Text G1 - Lite',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING', 'CONTINUED_PRE_TRAINING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-text-lite-v1',
#    'modelId': 'amazon.titan-text-lite-v1',
#    'modelName': 'Titan Text G1 - Lite',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-text-express-v1:0:8k',
#    'modelId': 'amazon.titan-text-express-v1:0:8k',
#    'modelName': 'Titan Text G1 - Express',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING', 'CONTINUED_PRE_TRAINING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-text-express-v1',
#    'modelId': 'amazon.titan-text-express-v1',
#    'modelName': 'Titan Text G1 - Express',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-embed-text-v1:2:8k',
#    'modelId': 'amazon.titan-embed-text-v1:2:8k',
#    'modelName': 'Titan Embeddings G1 - Text',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['EMBEDDING'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-embed-text-v1',
#    'modelId': 'amazon.titan-embed-text-v1',
#    'modelName': 'Titan Embeddings G1 - Text',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['EMBEDDING'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-embed-image-v1:0',
#    'modelId': 'amazon.titan-embed-image-v1:0',
#    'modelName': 'Titan Multimodal Embeddings G1',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['EMBEDDING'],
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-embed-image-v1',
#    'modelId': 'amazon.titan-embed-image-v1',
#    'modelName': 'Titan Multimodal Embeddings G1',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['EMBEDDING'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-image-generator-v1:0',
#    'modelId': 'amazon.titan-image-generator-v1:0',
#    'modelName': 'Titan Image Generator G1',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/amazon.titan-image-generator-v1',
#    'modelId': 'amazon.titan-image-generator-v1',
#    'modelName': 'Titan Image Generator G1',
#    'providerName': 'Amazon',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/stability.stable-diffusion-xl',
#    'modelId': 'stability.stable-diffusion-xl',
#    'modelName': 'SDXL 0.8',
#    'providerName': 'Stability AI',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'LEGACY'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/stability.stable-diffusion-xl-v0',
#    'modelId': 'stability.stable-diffusion-xl-v0',
#    'modelName': 'SDXL 0.8',
#    'providerName': 'Stability AI',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'LEGACY'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/stability.stable-diffusion-xl-v1:0',
#    'modelId': 'stability.stable-diffusion-xl-v1:0',
#    'modelName': 'SDXL 1.0',
#    'providerName': 'Stability AI',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/stability.stable-diffusion-xl-v1',
#    'modelId': 'stability.stable-diffusion-xl-v1',
#    'modelName': 'SDXL 1.0',
#    'providerName': 'Stability AI',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['IMAGE'],
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-grande-instruct',
#    'modelId': 'ai21.j2-grande-instruct',
#    'modelName': 'J2 Grande Instruct',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-jumbo-instruct',
#    'modelId': 'ai21.j2-jumbo-instruct',
#    'modelName': 'J2 Jumbo Instruct',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-mid',
#    'modelId': 'ai21.j2-mid',
#    'modelName': 'Jurassic-2 Mid',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-mid-v1',
#    'modelId': 'ai21.j2-mid-v1',
#    'modelName': 'Jurassic-2 Mid',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-ultra',
#    'modelId': 'ai21.j2-ultra',
#    'modelName': 'Jurassic-2 Ultra',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/ai21.j2-ultra-v1',
#    'modelId': 'ai21.j2-ultra-v1',
#    'modelName': 'Jurassic-2 Ultra',
#    'providerName': 'AI21 Labs',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-instant-v1:2:100k',
#    'modelId': 'anthropic.claude-instant-v1:2:100k',
#    'modelName': 'Claude Instant',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-instant-v1',
#    'modelId': 'anthropic.claude-instant-v1',
#    'modelName': 'Claude Instant',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2:0:18k',
#    'modelId': 'anthropic.claude-v2:0:18k',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2:0:100k',
#    'modelId': 'anthropic.claude-v2:0:100k',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2:1:18k',
#    'modelId': 'anthropic.claude-v2:1:18k',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2:1:200k',
#    'modelId': 'anthropic.claude-v2:1:200k',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2:1',
#    'modelId': 'anthropic.claude-v2:1',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2',
#    'modelId': 'anthropic.claude-v2',
#    'modelName': 'Claude',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-3-sonnet-20240229-v1:0',
#    'modelId': 'anthropic.claude-3-sonnet-20240229-v1:0',
#    'modelName': 'Claude 3 Sonnet',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-3-haiku-20240307-v1:0',
#    'modelId': 'anthropic.claude-3-haiku-20240307-v1:0',
#    'modelName': 'Claude 3 Haiku',
#    'providerName': 'Anthropic',
#    'inputModalities': ['TEXT', 'IMAGE'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.command-text-v14:7:4k',
#    'modelId': 'cohere.command-text-v14:7:4k',
#    'modelName': 'Command',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.command-text-v14',
#    'modelId': 'cohere.command-text-v14',
#    'modelName': 'Command',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.command-light-text-v14:7:4k',
#    'modelId': 'cohere.command-light-text-v14:7:4k',
#    'modelName': 'Command Light',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.command-light-text-v14',
#    'modelId': 'cohere.command-light-text-v14',
#    'modelName': 'Command Light',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.embed-english-v3',
#    'modelId': 'cohere.embed-english-v3',
#    'modelName': 'Embed English',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['EMBEDDING'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/cohere.embed-multilingual-v3',
#    'modelId': 'cohere.embed-multilingual-v3',
#    'modelName': 'Embed Multilingual',
#    'providerName': 'Cohere',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['EMBEDDING'],
#    'responseStreamingSupported': False,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-13b-chat-v1:0:4k',
#    'modelId': 'meta.llama2-13b-chat-v1:0:4k',
#    'modelName': 'Llama 2 Chat 13B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['PROVISIONED'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-13b-chat-v1',
#    'modelId': 'meta.llama2-13b-chat-v1',
#    'modelName': 'Llama 2 Chat 13B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-70b-chat-v1:0:4k',
#    'modelId': 'meta.llama2-70b-chat-v1:0:4k',
#    'modelName': 'Llama 2 Chat 70B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': [],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-70b-chat-v1',
#    'modelId': 'meta.llama2-70b-chat-v1',
#    'modelName': 'Llama 2 Chat 70B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-13b-v1:0:4k',
#    'modelId': 'meta.llama2-13b-v1:0:4k',
#    'modelName': 'Llama 2 13B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': [],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-13b-v1',
#    'modelId': 'meta.llama2-13b-v1',
#    'modelName': 'Llama 2 13B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': [],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-70b-v1:0:4k',
#    'modelId': 'meta.llama2-70b-v1:0:4k',
#    'modelName': 'Llama 2 70B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': ['FINE_TUNING'],
#    'inferenceTypesSupported': [],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/meta.llama2-70b-v1',
#    'modelId': 'meta.llama2-70b-v1',
#    'modelName': 'Llama 2 70B',
#    'providerName': 'Meta',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': [],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/mistral.mistral-7b-instruct-v0:2',
#    'modelId': 'mistral.mistral-7b-instruct-v0:2',
#    'modelName': 'Mistral 7B Instruct',
#    'providerName': 'Mistral AI',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}},
#   {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/mistral.mixtral-8x7b-instruct-v0:1',
#    'modelId': 'mistral.mixtral-8x7b-instruct-v0:1',
#    'modelName': 'Mixtral 8x7B Instruct',
#    'providerName': 'Mistral AI',
#    'inputModalities': ['TEXT'],
#    'outputModalities': ['TEXT'],
#    'responseStreamingSupported': True,
#    'customizationsSupported': [],
#    'inferenceTypesSupported': ['ON_DEMAND'],
#    'modelLifecycle': {'status': 'ACTIVE'}}]}

# %%
import boto3 
bedrock = boto3.client(service_name='bedrock')

bedrock.get_foundation_model(modelIdentifier='anthropic.claude-v2')
# Out:
# {'ResponseMetadata': {'RequestId': 'bcac4090-ef5d-4294-a449-d8561de738db',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 24 Mar 2024 06:36:23 GMT',
#    'content-type': 'application/json',
#    'content-length': '370',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'bcac4090-ef5d-4294-a449-d8561de738db'},
#   'RetryAttempts': 0},
#  'modelDetails': {'modelArn': 'arn:aws:bedrock:us-west-2::foundation-model/anthropic.claude-v2',
#   'modelId': 'anthropic.claude-v2',
#   'modelName': 'Claude',
#   'providerName': 'Anthropic',
#   'inputModalities': ['TEXT'],
#   'outputModalities': ['TEXT'],
#   'responseStreamingSupported': True,
#   'customizationsSupported': [],
#   'inferenceTypesSupported': ['ON_DEMAND'],
#   'modelLifecycle': {'status': 'ACTIVE'}}}

# %% [markdown]
# Two types of Orchestration of Bedrock.
#
# With Amazon Bedrock, you can enable a Retrieval-Augmented Generation (RAG)ß workflow by using knowledge bases to build contextual applications by using the reasoning capabilities of LLMs. To use a knowledge base, choose Orchestration in the left navigation pane and then Knowledge base. For more information, see Knowledge base for Amazon Bedrock.
#
# Agents for Amazon Bedrock enables developers to configure an agent to complete actions based on organization data and user input. For example you might create an agent to take actions to fulfill a customer's request. To use an Agent, choose Orchestration in the left navigation pane and then Agent. For more information, see Agents for Amazon Bedrock.
